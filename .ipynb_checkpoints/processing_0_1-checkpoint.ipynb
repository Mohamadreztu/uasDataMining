# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import preprocessing

csv_data = pd.read_csv("bankCustomer.csv")
array = csv_data.values

X = array[:,2:6]
Y = array[:,1:4]

# %%
print(csv_data)
# Out:
#     customerId geography  gender    balance  age  Credit Score Age Category
# 0     15634602    France  Female       0.00   42           619          Tua  \
# 1     15647311     Spain  Female   83807.86   41           608         Muda
# 2     15701354    France  Female  159660.80   42           502          Tua
# 3     15619304    France  Female       0.00   39           699         Muda
# 4     15737888     Spain  Female  125510.82   43           685          Tua
# 5     15574012     Spain    Male  113755.78   44           645          Tua
# 6     15592531    France    Male  115046.74   50           682          Tua
# 7     15656148   Germany  Female  142051.07   29           376         Muda
# 8     15792365    France    Male  134603.88   44           501          Tua
# 9     15592389    France    Male  102016.72   27           684         Muda
# 10    15767821    France    Male       0.00   31           528         Muda
# 11    15737173     Spain    Male       0.00   24           497         Muda
# 12    15632264    France  Female       0.00   34           476         Muda
# 13    15691483    France   Femal       0.00   25           549         Muda
# 14    15600882     Spain  Female  143129.41   35           635         Muda
# 15    15643966   Germany    Male  132602.88   45           616          Tua
# 16    15737452   Germany    Male       0.00   58           653          Tua
# 17    15788218     Spain  Female       0.00   24           549         Muda
# 18    15661507     Spain    Male       0.00   45           587          Tua
# 19    15568982    France  Female       0.00   58           736          Tua
#
#    CS Category
# 0       Tinggi
# 1       Tinggi
# 2       Rendah
# 3       Tinggi
# 4       Tinggi
# 5       Tinggi
# 6       Tinggi
# 7       Rendah
# 8       Rendah
# 9       Tinggi
# 10      Rendah
# 11      Rendah
# 12      Rendah
# 13      Rendah
# 14      Tinggi
# 15      Tinggi
# 16      Tinggi
# 17      Rendah
# 18      Tinggi
# 19      Tinggi

# %%
dataset = pd.DataFrame({
    'Customer ID': array[:, 0],
    'Geography': array[:, 1],
    'Gender': array[:, 2],
    'Balance': array[:, 3],
    'Age': array[:, 4],
    'Credit Score': array[:,5],
    'Age Category': array[:, 6],
    'CS Category': array[:, 7]
})

#print(dataset.duplicated().sum())
print("Sebelum di-Normalisasi:")
print(dataset.head(20))

min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))  # Inisialisasi normalisasi MinMax
data = min_max_scaler.fit_transform(array[:, 3:6])  # Transformasi MinMax untuk fitur Balance Age dan Creadit Score

dataset['Balance'] = data[:, 0]
dataset['Age'] = data[:, 1]
dataset['Credit Score'] = data[:, 2]

print("\nSetelah di-Normalisasi:")
print(dataset.head(20))

dataset.to_csv("bankCustomerPreprocessed.csv",encoding="utf8")
# Out:
# Sebelum di-Normalisasi:
#    Customer ID Geography  Gender    Balance Age Credit Score Age Category
# 0     15634602    France  Female        0.0  42          619          Tua  \
# 1     15647311     Spain  Female   83807.86  41          608         Muda
# 2     15701354    France  Female   159660.8  42          502          Tua
# 3     15619304    France  Female        0.0  39          699         Muda
# 4     15737888     Spain  Female  125510.82  43          685          Tua
# 5     15574012     Spain    Male  113755.78  44          645          Tua
# 6     15592531    France    Male  115046.74  50          682          Tua
# 7     15656148   Germany  Female  142051.07  29          376         Muda
# 8     15792365    France    Male  134603.88  44          501          Tua
# 9     15592389    France    Male  102016.72  27          684         Muda
# 10    15767821    France    Male        0.0  31          528         Muda
# 11    15737173     Spain    Male        0.0  24          497         Muda
# 12    15632264    France  Female        0.0  34          476         Muda
# 13    15691483    France   Femal        0.0  25          549         Muda
# 14    15600882     Spain  Female  143129.41  35          635         Muda
# 15    15643966   Germany    Male  132602.88  45          616          Tua
# 16    15737452   Germany    Male        0.0  58          653          Tua
# 17    15788218     Spain  Female        0.0  24          549         Muda
# 18    15661507     Spain    Male        0.0  45          587          Tua
# 19    15568982    France  Female        0.0  58          736          Tua
#
#    CS Category
# 0       Tinggi
# 1       Tinggi
# 2       Rendah
# 3       Tinggi
# 4       Tinggi
# 5       Tinggi
# 6       Tinggi
# 7       Rendah
# 8       Rendah
# 9       Tinggi
# 10      Rendah
# 11      Rendah
# 12      Rendah
# 13      Rendah
# 14      Tinggi
# 15      Tinggi
# 16      Tinggi
# 17      Rendah
# 18      Tinggi
# 19      Tinggi
#
# Setelah di-Normalisasi:
#    Customer ID Geography  Gender   Balance       Age  Credit Score
# 0     15634602    France  Female  0.000000  0.529412      0.675000  \
# 1     15647311     Spain  Female  0.524912  0.500000      0.644444
# 2     15701354    France  Female  1.000000  0.529412      0.350000
# 3     15619304    France  Female  0.000000  0.441176      0.897222
# 4     15737888     Spain  Female  0.786109  0.558824      0.858333
# 5     15574012     Spain    Male  0.712484  0.588235      0.747222
# 6     15592531    France    Male  0.720570  0.764706      0.850000
# 7     15656148   Germany  Female  0.889705  0.147059      0.000000
# 8     15792365    France    Male  0.843062  0.588235      0.347222
# 9     15592389    France    Male  0.638959  0.088235      0.855556
# 10    15767821    France    Male  0.000000  0.205882      0.422222
# 11    15737173     Spain    Male  0.000000  0.000000      0.336111
# 12    15632264    France  Female  0.000000  0.294118      0.277778
# 13    15691483    France   Femal  0.000000  0.029412      0.480556
# 14    15600882     Spain  Female  0.896459  0.323529      0.719444
# 15    15643966   Germany    Male  0.830529  0.617647      0.666667
# 16    15737452   Germany    Male  0.000000  1.000000      0.769444
# 17    15788218     Spain  Female  0.000000  0.000000      0.480556
# 18    15661507     Spain    Male  0.000000  0.617647      0.586111
# 19    15568982    France  Female  0.000000  1.000000      1.000000
#
#    Age Category CS Category
# 0           Tua      Tinggi
# 1          Muda      Tinggi
# 2           Tua      Rendah
# 3          Muda      Tinggi
# 4           Tua      Tinggi
# 5           Tua      Tinggi
# 6           Tua      Tinggi
# 7          Muda      Rendah
# 8           Tua      Rendah
# 9          Muda      Tinggi
# 10         Muda      Rendah
# 11         Muda      Rendah
# 12         Muda      Rendah
# 13         Muda      Rendah
# 14         Muda      Tinggi
# 15          Tua      Tinggi
# 16          Tua      Tinggi
# 17         Muda      Rendah
# 18          Tua      Tinggi
# 19          Tua      Tinggi

# %% [markdown]
# # Visualisasi Data

# %%
sns.histplot(data=csv_data, x="Credit Score")
plt.title("Sebelum di-Normalisasi")
plt.show()

sns.histplot(data=dataset, x="Age")
plt.title("Setelah di-Normalisasi")
plt.show()

# %%
sns.countplot(x="Age Category", hue="CS Category", data=dataset)
# Out:
# <Axes: xlabel='Age Category', ylabel='count'>
